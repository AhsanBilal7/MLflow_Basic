# %% [markdown]
# # For File

# %%
# Wine Quality Sample
def train(in_alpha, in_l1_ratio):
    import logging
    import warnings

    import numpy as np
    import pandas as pd
    from sklearn.linear_model import ElasticNet
    from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
    from sklearn.model_selection import train_test_split

    import mlflow
    import mlflow.sklearn
    from mlflow.models import infer_signature

    logging.basicConfig(level=logging.WARN)
    logger = logging.getLogger(__name__)

    def eval_metrics(actual, pred):
        rmse = np.sqrt(mean_squared_error(actual, pred))
        mae = mean_absolute_error(actual, pred)
        r2 = r2_score(actual, pred)
        return rmse, mae, r2

    warnings.filterwarnings("ignore")
    np.random.seed(40)

    # Read the wine-quality csv file from the URL
    csv_url = (
        "http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"
    )
    try:
        data = pd.read_csv(csv_url, sep=";")
    except Exception as e:
        logger.exception(
            "Unable to download training & test CSV, check your internet connection. Error: %s", e
        )

    # Split the data into training and test sets. (0.75, 0.25) split.
    train, test = train_test_split(data)

    # The predicted column is "quality" which is a scalar from [3, 9]
    train_x = train.drop(["quality"], axis=1)
    test_x = test.drop(["quality"], axis=1)
    train_y = train[["quality"]]
    test_y = test[["quality"]]

    # Set default values if no alpha is provided
    alpha = 0.5 if float(in_alpha) is None else float(in_alpha)

    # Set default values if no l1_ratio is provided
    l1_ratio = 0.5 if float(in_l1_ratio) is None else float(in_l1_ratio)

    # Useful for multiple runs (only doing one run in this sample notebook)
    with mlflow.start_run():
        # Execute ElasticNet
        lr = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, random_state=42)
        lr.fit(train_x, train_y)

        # Evaluate Metrics
        predicted_qualities = lr.predict(test_x)
        (rmse, mae, r2) = eval_metrics(test_y, predicted_qualities)

        # Print out metrics
        print(f"Elasticnet model (alpha={alpha:f}, l1_ratio={l1_ratio:f}):")
        print("  RMSE: %s" % rmse)
        print("  MAE: %s" % mae)
        print("  R2: %s" % r2)

        # Infer model signature
        predictions = lr.predict(train_x)
        signature = infer_signature(train_x, predictions)

        # Log parameter, metrics, and model to MLflow
        mlflow.log_param("alpha", alpha)
        mlflow.log_param("l1_ratio", l1_ratio)
        mlflow.log_metric("rmse", rmse)
        mlflow.log_metric("r2", r2)
        mlflow.log_metric("mae", mae)

        mlflow.sklearn.log_model(lr, "model", signature=signature)

# %%
# train(0.2, 0.2)
# train(0.5, 0.7)
# train(0.7, 0.5)
# Out:
# Elasticnet model (alpha=0.200000, l1_ratio=0.200000):
#   RMSE: 0.7336400911821402
#   MAE: 0.5643841279275428
#   R2: 0.2373946606358417
# Elasticnet model (alpha=0.500000, l1_ratio=0.700000):
#   RMSE: 0.829586285479097
#   MAE: 0.6627028304266677
#   R2: 0.024882710417617915
# Elasticnet model (alpha=0.700000, l1_ratio=0.500000):
#   RMSE: 0.8298921852578499
#   MAE: 0.6629780128961713
#   R2: 0.024163452726365664

# %% [markdown]
# # For Remote Server

# %%
# !set MLFLOW_TRACKING_URI=https://dagshub.com/AhsanBilal7/MLflow_Basic.mlflow 
# !set MLFLOW_TRACKING_USERNAME=AhsanBilal7 
# !set MLFLOW_TRACKING_PASSWORD=ba91b095c98ccb1c761d6239a0b4b20b5541abf1

# %%
# Wine Quality Sample
def train(in_alpha, in_l1_ratio):
    import logging
    import warnings
    from urllib.parse import urlparse
    import numpy as np
    import pandas as pd
    from sklearn.linear_model import ElasticNet
    from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
    from sklearn.model_selection import train_test_split

    import mlflow
    import mlflow.sklearn

    logging.basicConfig(level=logging.WARN)
    logger = logging.getLogger(__name__)

    def eval_metrics(actual, pred):
        rmse = np.sqrt(mean_squared_error(actual, pred))
        mae = mean_absolute_error(actual, pred)
        r2 = r2_score(actual, pred)
        return rmse, mae, r2

    warnings.filterwarnings("ignore")
    np.random.seed(40)

    # Read the wine-quality csv file from the URL
    csv_url = (
        "http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"
    )
    try:
        data = pd.read_csv(csv_url, sep=";")
    except Exception as e:
        logger.exception(
            "Unable to download training & test CSV, check your internet connection. Error: %s", e
        )

    # Split the data into training and test sets. (0.75, 0.25) split.
    train, test = train_test_split(data)

    # The predicted column is "quality" which is a scalar from [3, 9]
    train_x = train.drop(["quality"], axis=1)
    test_x = test.drop(["quality"], axis=1)
    train_y = train[["quality"]]
    test_y = test[["quality"]]

    # Set default values if no alpha is provided
    alpha = 0.5 if float(in_alpha) is None else float(in_alpha)

    # Set default values if no l1_ratio is provided
    l1_ratio = 0.5 if float(in_l1_ratio) is None else float(in_l1_ratio)

    # Useful for multiple runs (only doing one run in this sample notebook)
    with mlflow.start_run():
        # Execute ElasticNet
        lr = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, random_state=42)
        lr.fit(train_x, train_y)

        # Evaluate Metrics
        predicted_qualities = lr.predict(test_x)
        (rmse, mae, r2) = eval_metrics(test_y, predicted_qualities)

        # Print out metrics
        print(f"Elasticnet model (alpha={alpha:f}, l1_ratio={l1_ratio:f}):")
        print("  RMSE: %s" % rmse)
        print("  MAE: %s" % mae)
        print("  R2: %s" % r2)

        # Infer model signature
        predictions = lr.predict(train_x)

        # Log parameter, metrics, and model to MLflow
        mlflow.log_param("alpha", alpha)
        mlflow.log_param("l1_ratio", l1_ratio)
        mlflow.log_metric("rmse", rmse)
        mlflow.log_metric("r2", r2)
        mlflow.log_metric("mae", mae)
        uri = "https://dagshub.com/AhsanBilal7/MLflow_Basic.mlflow"
        mlflow.set_tracking_uri(uri)
        tracking_uri_type = urlparse(mlflow.get_tracking_uri()).scheme
        if tracking_uri_type != 'file':
            mlflow.sklearn.log_model(lr, "model", registered_model_name = "Ahsan_Elasticnet")
        else:
            mlflow.sklearn.log_model(lr, "model", signature=signature)

# %%
# train(0.2, 0.2)
# train(0.5, 0.7)
# train(0.7, 0.5)
# Out:
# Elasticnet model (alpha=0.200000, l1_ratio=0.200000):
#   RMSE: 0.7336400911821402
#   MAE: 0.5643841279275428
#   R2: 0.2373946606358417
# ---------------------------------------------------------------------------
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\urllib3\connectionpool.py:889, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     888     log.debug("Retry: %s", url)
# --> 889     return self.urlopen(
#     890         method,
#     891         url,
#     892         body,
#     893         headers,
#     894         retries=retries,
#     895         redirect=redirect,
#     896         assert_same_host=assert_same_host,
#     897         timeout=timeout,
#     898         pool_timeout=pool_timeout,
#     899         release_conn=release_conn,
#     900         chunked=chunked,
#     901         body_pos=body_pos,
#     902         **response_kw
#     903     )
#     905 return response
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\urllib3\connectionpool.py:889, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     888     log.debug("Retry: %s", url)
# --> 889     return self.urlopen(
#     890         method,
#     891         url,
#     892         body,
#     893         headers,
#     894         retries=retries,
#     895         redirect=redirect,
#     896         assert_same_host=assert_same_host,
#     897         timeout=timeout,
#     898         pool_timeout=pool_timeout,
#     899         release_conn=release_conn,
#     900         chunked=chunked,
#     901         body_pos=body_pos,
#     902         **response_kw
#     903     )
#     905 return response
#
#     [... skipping similar frames: HTTPConnectionPool.urlopen at line 889 (2 times)]
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\urllib3\connectionpool.py:889, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     888     log.debug("Retry: %s", url)
# --> 889     return self.urlopen(
#     890         method,
#     891         url,
#     892         body,
#     893         headers,
#     894         retries=retries,
#     895         redirect=redirect,
#     896         assert_same_host=assert_same_host,
#     897         timeout=timeout,
#     898         pool_timeout=pool_timeout,
#     899         release_conn=release_conn,
#     900         chunked=chunked,
#     901         body_pos=body_pos,
#     902         **response_kw
#     903     )
#     905 return response
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\urllib3\connectionpool.py:879, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     878 try:
# --> 879     retries = retries.increment(method, url, response=response, _pool=self)
#     880 except MaxRetryError:
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='dagshub.com', port=443): Max retries exceeded with url: /AhsanBilal7/MLflow_Basic.mlflow/api/2.0/mlflow/runs/get?run_uuid=17404403911b47508564ca21619214d9&run_id=17404403911b47508564ca21619214d9 (Caused by ResponseError('too many 500 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\utils\rest_utils.py:107, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, **kwargs)
#     106 try:
# --> 107     return _get_http_response_with_retries(
#     108         method,
#     109         url,
#     110         max_retries,
#     111         backoff_factor,
#     112         backoff_jitter,
#     113         retry_codes,
#     114         raise_on_status,
#     115         headers=headers,
#     116         verify=host_creds.verify,
#     117         timeout=timeout,
#     118         **kwargs,
#     119     )
#     120 except requests.exceptions.Timeout as to:
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\utils\request_utils.py:197, in _get_http_response_with_retries(method, url, max_retries, backoff_factor, backoff_jitter, retry_codes, raise_on_status, allow_redirects, **kwargs)
#     195 allow_redirects = env_value if allow_redirects is None else allow_redirects
# --> 197 return session.request(method, url, allow_redirects=allow_redirects, **kwargs)
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\requests\adapters.py:510, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     509 if isinstance(e.reason, ResponseError):
# --> 510     raise RetryError(e, request=request)
#     512 if isinstance(e.reason, _ProxyError):
#
# RetryError: HTTPSConnectionPool(host='dagshub.com', port=443): Max retries exceeded with url: /AhsanBilal7/MLflow_Basic.mlflow/api/2.0/mlflow/runs/get?run_uuid=17404403911b47508564ca21619214d9&run_id=17404403911b47508564ca21619214d9 (Caused by ResponseError('too many 500 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# MlflowException                           Traceback (most recent call last)
# Cell In[1], line 82, in train(in_alpha, in_l1_ratio)
#      81 if tracking_uri_type != 'file':
# ---> 82     mlflow.sklearn.log_model(lr, "model", registered_model_name = "Ahsan_Elasticnet")
#      83 else:
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\sklearn\__init__.py:411, in log_model(sk_model, artifact_path, conda_env, code_paths, serialization_format, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements, pyfunc_predict_fn, metadata)
#     347 """
#     348 Log a scikit-learn model as an MLflow artifact for the current run. Produces an MLflow Model
#     349 containing the following flavors:
#    (...)
#     409
#     410 """
# --> 411 return Model.log(
#     412     artifact_path=artifact_path,
#     413     flavor=mlflow.sklearn,
#     414     sk_model=sk_model,
#     415     conda_env=conda_env,
#     416     code_paths=code_paths,
#     417     serialization_format=serialization_format,
#     418     registered_model_name=registered_model_name,
#     419     signature=signature,
#     420     input_example=input_example,
#     421     await_registration_for=await_registration_for,
#     422     pip_requirements=pip_requirements,
#     423     extra_pip_requirements=extra_pip_requirements,
#     424     pyfunc_predict_fn=pyfunc_predict_fn,
#     425     metadata=metadata,
#     426 )
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\models\model.py:620, in Model.log(cls, artifact_path, flavor, registered_model_name, await_registration_for, metadata, **kwargs)
#     619 flavor.save_model(path=local_path, mlflow_model=mlflow_model, **kwargs)
# --> 620 mlflow.tracking.fluent.log_artifacts(local_path, mlflow_model.artifact_path)
#     621 try:
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\tracking\fluent.py:1030, in log_artifacts(local_dir, artifact_path)
#    1029 run_id = _get_or_start_run().info.run_id
# -> 1030 MlflowClient().log_artifacts(run_id, local_dir, artifact_path)
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\tracking\client.py:1195, in MlflowClient.log_artifacts(self, run_id, local_dir, artifact_path)
#    1154 """
#    1155 Write a directory of files to the remote ``artifact_uri``.
#    1156
#    (...)
#    1193     is_dir: True
#    1194 """
# -> 1195 self._tracking_client.log_artifacts(run_id, local_dir, artifact_path)
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\tracking\_tracking_service\client.py:538, in TrackingServiceClient.log_artifacts(self, run_id, local_dir, artifact_path)
#     532 """
#     533 Write a directory of files to the remote ``artifact_uri``.
#     534
#     535 :param local_dir: Path to the directory of files to write.
#     536 :param artifact_path: If provided, the directory in ``artifact_uri`` to write to.
#     537 """
# --> 538 self._get_artifact_repo(run_id).log_artifacts(local_dir, artifact_path)
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\tracking\_tracking_service\client.py:502, in TrackingServiceClient._get_artifact_repo(self, run_id)
#     501 else:
# --> 502     run = self.get_run(run_id)
#     503     artifact_uri = add_databricks_profile_info_to_artifact_uri(
#     504         run.info.artifact_uri, self.tracking_uri
#     505     )
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\tracking\_tracking_service\client.py:73, in TrackingServiceClient.get_run(self, run_id)
#      72 _validate_run_id(run_id)
# ---> 73 return self.store.get_run(run_id)
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\store\tracking\rest_store.py:137, in RestStore.get_run(self, run_id)
#     136 req_body = message_to_json(GetRun(run_uuid=run_id, run_id=run_id))
# --> 137 response_proto = self._call_endpoint(GetRun, req_body)
#     138 return Run.from_proto(response_proto.run)
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\store\tracking\rest_store.py:59, in RestStore._call_endpoint(self, api, json_body)
#      58 response_proto = api.Response()
# ---> 59 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\utils\rest_utils.py:215, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers)
#     214     call_kwargs["params"] = json_body
# --> 215     response = http_request(**call_kwargs)
#     216 else:
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\utils\rest_utils.py:129, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, **kwargs)
#     128 except Exception as e:
# --> 129     raise MlflowException(f"API request to {url} failed with exception {e}")
#
# MlflowException: API request to https://dagshub.com/AhsanBilal7/MLflow_Basic.mlflow/api/2.0/mlflow/runs/get failed with exception HTTPSConnectionPool(host='dagshub.com', port=443): Max retries exceeded with url: /AhsanBilal7/MLflow_Basic.mlflow/api/2.0/mlflow/runs/get?run_uuid=17404403911b47508564ca21619214d9&run_id=17404403911b47508564ca21619214d9 (Caused by ResponseError('too many 500 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# MlflowException                           Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 train(0.2, 0.2)
#       2 train(0.5, 0.7)
#       3 train(0.7, 0.5)
#
# Cell In[1], line 84, in train(in_alpha, in_l1_ratio)
#      82     mlflow.sklearn.log_model(lr, "model", registered_model_name = "Ahsan_Elasticnet")
#      83 else:
# ---> 84     mlflow.sklearn.log_model(lr, "model", signature=signature)
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\tracking\fluent.py:190, in ActiveRun.__exit__(self, exc_type, exc_val, exc_tb)
#     188 def __exit__(self, exc_type, exc_val, exc_tb):
#     189     status = RunStatus.FINISHED if exc_type is None else RunStatus.FAILED
# --> 190     end_run(RunStatus.to_string(status))
#     191     return exc_type is None
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\tracking\fluent.py:446, in end_run(status)
#     444 run = _active_run_stack.pop()
#     445 _last_active_run_id = run.info.run_id
# --> 446 MlflowClient().set_terminated(_last_active_run_id, status)
#     447 if _last_active_run_id in run_id_to_system_metrics_monitor:
#     448     system_metrics_monitor = run_id_to_system_metrics_monitor.pop(_last_active_run_id)
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\tracking\client.py:1916, in MlflowClient.set_terminated(self, run_id, status, end_time)
#    1871 def set_terminated(
#    1872     self, run_id: str, status: Optional[str] = None, end_time: Optional[int] = None
#    1873 ) -> None:
#    1874     """Set a run's status to terminated.
#    1875
#    1876     :param status: A string value of :py:class:`mlflow.entities.RunStatus`.
#    (...)
#    1914         status: KILLED
#    1915     """
# -> 1916     self._tracking_client.set_terminated(run_id, status, end_time)
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\tracking\_tracking_service\client.py:575, in TrackingServiceClient.set_terminated(self, run_id, status, end_time)
#     573 end_time = end_time if end_time else get_current_time_millis()
#     574 status = status if status else RunStatus.to_string(RunStatus.FINISHED)
# --> 575 self.store.update_run_info(
#     576     run_id,
#     577     run_status=RunStatus.from_string(status),
#     578     end_time=end_time,
#     579     run_name=None,
#     580 )
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\store\tracking\rest_store.py:151, in RestStore.update_run_info(self, run_id, run_status, end_time, run_name)
#     141 """Updates the metadata of the specified run."""
#     142 req_body = message_to_json(
#     143     UpdateRun(
#     144         run_uuid=run_id,
#    (...)
#     149     )
#     150 )
# --> 151 response_proto = self._call_endpoint(UpdateRun, req_body)
#     152 return RunInfo.from_proto(response_proto.run_info)
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\store\tracking\rest_store.py:59, in RestStore._call_endpoint(self, api, json_body)
#      57 endpoint, method = _METHOD_TO_INFO[api]
#      58 response_proto = api.Response()
# ---> 59 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\utils\rest_utils.py:219, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers)
#     217     call_kwargs["json"] = json_body
#     218     response = http_request(**call_kwargs)
# --> 219 response = verify_rest_response(response, endpoint)
#     220 js_dict = json.loads(response.text)
#     221 parse_dict(js_dict=js_dict, message=response_proto)
#
# File c:\Users\Pc\miniconda3\envs\tf\lib\site-packages\mlflow\utils\rest_utils.py:157, in verify_rest_response(response, endpoint)
#     152     else:
#     153         base_msg = (
#     154             f"API request to endpoint {endpoint} "
#     155             f"failed with error code {response.status_code} != 200"
#     156         )
# --> 157         raise MlflowException(
#     158             f"{base_msg}. Response body: '{response.text}'",
#     159             error_code=get_error_code(response.status_code),
#     160         )
#     162 # Skip validation for endpoints (e.g. DBFS file-download API) which may return a non-JSON
#     163 # response
#     164 if endpoint.startswith(_REST_API_PATH_PREFIX) and not _can_parse_as_json_object(response.text):
#
# MlflowException: API request to endpoint /api/2.0/mlflow/runs/update failed with error code 403 != 200. Response body: ''
